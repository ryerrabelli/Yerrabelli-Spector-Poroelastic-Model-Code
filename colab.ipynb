# %%
#/content/drive/MyDrive/Computer Backups/Rahul Yerrabelli drive/Academics/Work/SpectorMechanicsLab/SpectorResearch/Computations/SpectorLog/Yerrabelli-Spector-Porelastic-Model-Code
from google.colab import drive
#drive.mount("/content/drive")
#drive.mount("/content/drive/MyDrive/Computer Backups/Rahul Yerrabelli drive/Academics/Work/SpectorMechanicsLab/SpectorResearch/Computations/SpectorLog/Yerrabelli-Spector-Porelastic-Model-Code")

# !cd "/content/drive/MyDrive/Computer Backups/Rahul Yerrabelli drive/Academics/Work/SpectorMechanicsLab/SpectorResearch/Computations/SpectorLog/Yerrabelli-Spector-Porelastic-Model-Code"

import numpy as np
from main2 import sigbar

# %%
import time as timer
# inputting a value of time=0 doesn't error (just returns None/NaN), but takes longer (about 2x as much) on python; not really MATLAB though
times=np.array([2,3])
times = np.arange(0.05, 5.05, 0.05)
from euler_inversion import euler_inversion
t1=timer.time();
ret=euler_inversion(sigbar, times)
print(ret)
t2=timer.time()-t1
print(t2)
# Out:
# [-5.6218171  -4.29220284 -3.72086601 -3.39126382 -3.17398138 -3.01965544
#  -2.9049515  -2.81707255 -2.74741951 -2.69228643 -2.64751299 -2.61144245
#  -2.58186579 -2.55809356 -2.53873026 -2.52319149 -2.51110713 -2.5016932
#  -2.49475306 -2.49104796 -2.49762607 -2.49193393 -2.47680004 -2.45397655
#  -2.42495696 -2.38818803 -2.34268804 -2.29409945 -2.23830769 -2.17509855
#  -2.10846012 -2.03330741 -1.95432804 -1.86839449 -1.77683502 -1.68015415
#  -1.57673454 -1.46817175 -1.3538625  -1.23339747 -1.10745272 -0.97575132
#  -0.83810423 -0.69467666 -0.5454815  -0.3904139  -0.22954001 -0.06265407
#   0.11007962  0.28875736  0.47337914  0.66401639  0.86066518  1.06337539
#   1.27211844  1.48708877  1.70813808  1.93540903  2.16888798  2.40858981
#   2.65462317  2.90703311  3.16571452  3.4308813   3.70249962  3.98061595
#   4.26524329  4.55645445  4.85432988  5.15884964  5.47009802  5.78809609
#   6.11291896  6.44461412  6.78316192  7.12869552  7.48122997  7.84077946
# ...

# %%
import matplotlib.pyplot as plt

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(times, ret)
plt.show()
